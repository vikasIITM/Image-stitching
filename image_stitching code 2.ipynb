# %%
import numpy as np
import cv2
import glob
import imutils
from google.colab.patches import cv2_imshow

# %%
img1=cv2.imread("/content/drive/MyDrive/image/first.jpg",cv2.IMREAD_COLOR)

# %%
img2=cv2.imread("/content/drive/MyDrive/image/second.jpg",cv2.IMREAD_COLOR)

# %%
img3=cv2.imread("/content/drive/MyDrive/image/third.jpg",cv2.IMREAD_COLOR)

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=1072x1440 at 0x7FEDA5B21890>

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=1072x1440 at 0x7FEDA52A8390>

# %%
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=1072x1440 at 0x7FEDA3A2C0D0>

# %%
images=[]
images.append(img1)
images.append(img2)
images.append(img3)

# %%
stitcher=cv2.Stitcher.create()
ret,pano=stitcher.stitch(images)

# %%
if ret==cv2.STITCHER_OK:
  cv2_imshow(pano)
  
else:
 print("Images could not be stitched ")
 print("Image does not have enough common keypoints")
# Out:
# <PIL.Image.Image image mode=RGB size=1832x1272 at 0x7FEDA3A2CB90>
